# %%
import pandas as pd

# %% [markdown]
# # Leitura de Arquivo

# %%
# !cat data/salaries.csv

# %%
dados_salarios = pd.read_table("data/salaries.csv", delimiter=";")

# %% [markdown]
# # Criação de histograma

# %%
dados_salarios["Administrador"].hist(bins=10) # função hist responsável por criar um histograma
