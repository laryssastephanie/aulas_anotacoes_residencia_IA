# %%
import pandas as pd
import numpy as np

# %%
df_education = pd.read_csv('data/EducationAndEnviron_Data.csv', sep=';')

# %%
df_education.head()
# Out:
#                                           SeriesName      SeriesCode  \
# 0  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.ZS
# 1  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.ZS
# 2  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.ZS
# 3  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.ZS
# 4  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.ZS
#
#           CountryName CountryCode    Year  Value
# 0              Brazil         BRA  1970.0    NaN
# 1               China         CHN  1970.0    NaN
# 2               India         IND  1970.0    NaN
# 3  Russian Federation         RUS  1970.0    NaN
# 4        South Africa         ZAF  1970.0    NaN

# %%
metrics = df_education['SeriesName']
metrics.shape
# Out:
# (71500,)

# %%
df_mask = df_education['CountryCode'] == "BRA"
df_edu_bra = df_education[df_mask]

# %%
df_edu_bra.dropna(inplace=True)
df_edu_bra
# Out:
# <ipython-input-7-24071626af3b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_edu_bra.dropna(inplace=True)
#                                               SeriesName         SeriesCode  \
# 55                    Agricultural land (% of land area)     AG.LND.AGRI.ZS
# 60                            Agricultural land (sq. km)     AG.LND.AGRI.K2
# 65                      Agricultural machinery, tractors     AG.AGR.TRAC.NO
# 70     Agricultural machinery, tractors per 100 sq. k...     AG.LND.TRAC.ZS
# 75           Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# ...                                                  ...                ...
# 71155                 Rural population growth (annual %)     SP.RUR.TOTL.ZG
# ...

# %% [markdown]
# codigo pra gerar o df com os países e os valores pra cada ano:
#
# (
#     edu
#     .query("SeriesName == 'CO2 emissions (kt)'")
#     .groupby(['CountryCode', 'Year'])
#     .sum()
#     .unstack()
#     .T
#     .xs('Value')
# )

# %%
df_public_inv = pd.read_csv('data/PublicSector_Indicators.csv', sep=';')

# %%
metrics_2 = df_public_inv['SeriesName']
metrics_2.shape
# Out:
# (81500,)

# %%
df_mask_2 = df_public_inv['CountryCode'] == "BRA"
df_public_inv_bra = df_public_inv[df_mask_2]

# %%
df_public_inv_bra.dropna(inplace=True)
df_public_inv_bra
# Out:
# <ipython-input-12-0cd164e9c302>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_public_inv_bra.dropna(inplace=True)
#                                               SeriesName         SeriesCode  \
# 20               Air transport, freight (million ton-km)  IS.AIR.GOOD.MT.K1
# 25                     Air transport, passengers carried        IS.AIR.PSGR
# 30     Air transport, registered carrier departures w...        IS.AIR.DPRT
# 60           Arms imports (SIPRI trend indicator values)     MS.MIL.MPRT.KD
# 650                        Fixed telephone subscriptions        IT.MLT.MAIN
# ...                                                  ...                ...
# 81470  Vulnerable employment, male (% of male employm...  SL.EMP.VULN.MA.ZS
# ...

# %%
df_concat = pd.concat([df_edu_bra, df_public_inv_bra])

# %%
df_concat
# Out:
#                                               SeriesName         SeriesCode  \
# 55                    Agricultural land (% of land area)     AG.LND.AGRI.ZS
# 60                            Agricultural land (sq. km)     AG.LND.AGRI.K2
# 65                      Agricultural machinery, tractors     AG.AGR.TRAC.NO
# 70     Agricultural machinery, tractors per 100 sq. k...     AG.LND.TRAC.ZS
# 75           Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# ...                                                  ...                ...
# 81470  Vulnerable employment, male (% of male employm...  SL.EMP.VULN.MA.ZS
# 81475  Vulnerable employment, total (% of total emplo...     SL.EMP.VULN.ZS
# 81480  Wage and salaried workers, female (% of female...  SL.EMP.WORK.FE.ZS
# 81485  Wage and salaried workers, male (% of male emp...  SL.EMP.WORK.MA.ZS
# 81490  Wage and salaried workers, total (% of total e...     SL.EMP.WORK.ZS
#
#       CountryName CountryCode    Year         Value
# ...
